# %%
import pandas as pd
import os

# %%
SCRIPT_DIR_PATH = os.getcwd()
PARENT_DIR_PATH = os.path.dirname(SCRIPT_DIR_PATH)
TABLEAU_DATA_DIR_PATH = os.path.join(PARENT_DIR_PATH, "tableau/data")
SSP_RUN_OUTPUT = ""

# %%
decomposed_df = pd.read_csv(os.path.join(TABLEAU_DATA_DIR_PATH, "decomposed_emissions_libya_2022_sisepuede_results_sisepuede_run_2025-09-26T10;29;45.200029_WIDE_INPUTS_OUTPUTS.csv"))
decomposed_df.head()
# Out:
#    strategy_id  primary_id     Edgar_Class   CSC.Sector CSC.Subsector  \
# 0          0.0         0.0  AG - Crops:CH4  Agriculture    AG - Crops
# 1          0.0         0.0  AG - Crops:CH4  Agriculture    AG - Crops
# 2          0.0         0.0  AG - Crops:CH4  Agriculture    AG - Crops
# 3          0.0         0.0  AG - Crops:CH4  Agriculture    AG - Crops
# 4          0.0         0.0  AG - Crops:CH4  Agriculture    AG - Crops
#
#       value  Year  Gas  design_id  future_id          strategy Code Contry  \
# 0  0.000293  2022  CH4        0.0        0.0  Strategy TX:BASE  LBY  libya
# 1  0.000284  2023  CH4        0.0        0.0  Strategy TX:BASE  LBY  libya
# 2  0.000315  2024  CH4        0.0        0.0  Strategy TX:BASE  LBY  libya
# 3  0.000323  2025  CH4        0.0        0.0  Strategy TX:BASE  LBY  libya
# 4  0.000332  2026  CH4        0.0        0.0  Strategy TX:BASE  LBY  libya
#
#       source  value_original  value_hp
# 0  SISEPUEDE        0.000293       NaN
# ...

# %%
decomposed_df["CSC.Subsector"].unique()
# Out:
# array(['AG - Crops', 'AG - Livestock', 'CCSQ', 'EN - Building',
#        'EN - Electricity/Heat', 'EN - Fugitive Emissions',
#        'EN - Manufacturing/Construction', 'EN - Other',
#        'EN - Transportation', 'IN - Industrial Processes',
#        'LULUCF - Deforestation', 'LULUCF - Forest Land', 'LULUCF - HWP',
#        'LULUCF - Organic Soil', 'LULUCF - Other Land', 'UNACCOUNTED',
#        'Waste - Solid Waste', 'Waste - Wastewater Treatment'],
#       dtype=object)

# %%
ippu_decomposed_df = decomposed_df[decomposed_df["CSC.Subsector"] == "IN - Industrial Processes"]
ippu_decomposed_df.head()
# Out:
#       strategy_id  primary_id                     Edgar_Class  \
# 1274          0.0         0.0  IN - Industrial Processes:C2F6
# 1275          0.0         0.0  IN - Industrial Processes:C2F6
# 1276          0.0         0.0  IN - Industrial Processes:C2F6
# 1277          0.0         0.0  IN - Industrial Processes:C2F6
# 1278          0.0         0.0  IN - Industrial Processes:C2F6
#
#                 CSC.Sector              CSC.Subsector     value  Year   Gas  \
# 1274  Industrial Processes  IN - Industrial Processes  0.149696  2022  C2F6
# 1275  Industrial Processes  IN - Industrial Processes  0.145223  2023  C2F6
# 1276  Industrial Processes  IN - Industrial Processes  0.142560  2024  C2F6
# 1277  Industrial Processes  IN - Industrial Processes  0.140804  2025  C2F6
# 1278  Industrial Processes  IN - Industrial Processes  0.140086  2026  C2F6
#
#       design_id  future_id          strategy Code Contry     source  \
# ...

# %%
ippu_filtered_df = ippu_decomposed_df[ippu_decomposed_df["Year"] == 2022]
ippu_filtered_df.head()
# Out:
#       strategy_id  primary_id                       Edgar_Class  \
# 1274          0.0         0.0    IN - Industrial Processes:C2F6
# 1323          0.0         0.0  IN - Industrial Processes:C2H3F3
# 1372          0.0         0.0   IN - Industrial Processes:C2HF5
# 1421          0.0         0.0    IN - Industrial Processes:C3F8
# 1470          0.0         0.0  IN - Industrial Processes:C3H2F6
#
#                 CSC.Sector              CSC.Subsector     value  Year     Gas  \
# 1274  Industrial Processes  IN - Industrial Processes  0.149696  2022    C2F6
# 1323  Industrial Processes  IN - Industrial Processes  0.149696  2022  C2H3F3
# 1372  Industrial Processes  IN - Industrial Processes  0.149696  2022   C2HF5
# 1421  Industrial Processes  IN - Industrial Processes  0.149696  2022    C3F8
# 1470  Industrial Processes  IN - Industrial Processes  0.149696  2022  C3H2F6
#
#       design_id  future_id          strategy Code Contry     source  \
# ...

# %%
ippu_filtered_df.strategy.unique()
# Out:
# array(['Strategy TX:BASE', 'All Actions', 'Historical'], dtype=object)

# %%
ippu_filtered_df.groupby("strategy")["value"].sum()
# Out:
# strategy
# All Actions         5.669226
# Historical          7.615280
# Strategy TX:BASE    5.669226
# Name: value, dtype: float64

# %%
ippu_filtered_df[ippu_filtered_df["strategy"] == "Historical"]
# Out:
#       strategy_id  primary_id                    Edgar_Class  \
# 7538          NaN         NaN  IN - Industrial Processes:CH4
# 7561          NaN         NaN  IN - Industrial Processes:CO2
# 7584          NaN         NaN  IN - Industrial Processes:HFC
# 7607          NaN         NaN  IN - Industrial Processes:N2O
# 7630          NaN         NaN  IN - Industrial Processes:SF6
#
#                 CSC.Sector              CSC.Subsector     value  Year  Gas  \
# 7538  Industrial Processes  IN - Industrial Processes  0.003465  2022  CH4
# 7561  Industrial Processes  IN - Industrial Processes  2.499458  2022  CO2
# 7584  Industrial Processes  IN - Industrial Processes  4.191501  2022  HFC
# 7607  Industrial Processes  IN - Industrial Processes  0.360349  2022  N2O
# 7630  Industrial Processes  IN - Industrial Processes  0.560506  2022  SF6
#
#       design_id  future_id    strategy Code Contry source  value_original  \
# ...

# %%
ippu_filtered_df[(ippu_filtered_df["strategy"] == "Strategy TX:BASE") & (~ippu_filtered_df["Gas"].isin(["CH4", "CO2", "N2O", "SF6"]))]["value"].sum()
# Out:
# np.float64(2.2454469466071436)
